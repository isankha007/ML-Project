# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sqlalchemy import create_engine

# %%
# db_host = '18.136.56.185'
# username = 'dm_team'
# user_pass = 'dm_team123#'
# db_name = 'ITSM'

# conn = create_engine('mysql+pymysql://'+username+':'+user_pass+'@'+db_host)
# stmt="show databases"  #"select * from information_schema.tables"
# df0=pd.read_sql(stmt,conn)
# df0
# Out:
#              Database
# 0  information_schema
# 1        project_itsm

# %%
# db_host = '18.136.56.185'
# username = 'dm_team'
# user_pass = 'dm_team123#'
# db_name = 'project_itsm'

# conn = create_engine('mysql+pymysql://'+username+':'+user_pass+'@'+db_host+'/'+db_name)
# stmt="select * from information_schema.tables"
# df0=pd.read_sql(stmt,conn)
# df0.tail()
# Out:
#    TABLE_CATALOG        TABLE_SCHEMA                TABLE_NAME   TABLE_TYPE  \
# 55           def  information_schema   INNODB_SYS_FOREIGN_COLS  SYSTEM VIEW
# 56           def  information_schema         INNODB_SYS_TABLES  SYSTEM VIEW
# 57           def  information_schema  INNODB_BUFFER_POOL_STATS  SYSTEM VIEW
# 58           def  information_schema          INNODB_FT_CONFIG  SYSTEM VIEW
# 59           def        project_itsm              dataset_list   BASE TABLE
#
#     ENGINE  VERSION ROW_FORMAT  TABLE_ROWS  AVG_ROW_LENGTH  DATA_LENGTH  ...  \
# 55  MEMORY       10      Fixed         NaN            1748            0  ...
# 56  MEMORY       10      Fixed         NaN            2060            0  ...
# 57  MEMORY       10      Fixed         NaN             257            0  ...
# 58  MEMORY       10      Fixed         NaN            1163            0  ...
# 59  InnoDB       10    Compact     41932.0             262     11026432  ...
#
#     INDEX_LENGTH  DATA_FREE  AUTO_INCREMENT         CREATE_TIME UPDATE_TIME  \
# 55             0          0            None 2019-07-30 02:28:13         NaT
# 56             0          0            None 2019-07-30 02:28:13         NaT
# 57             0          0            None 2019-07-30 02:28:13         NaT
# 58             0          0            None 2019-07-30 02:28:13         NaT
# 59             0    4194304            None 2018-07-25 13:01:11         NaT
#
#    CHECK_TIME    TABLE_COLLATION CHECKSUM  CREATE_OPTIONS TABLE_COMMENT
# 55       None    utf8_general_ci     None   max_rows=9597
# 56       None    utf8_general_ci     None   max_rows=8144
# 57       None    utf8_general_ci     None  max_rows=65280
# 58       None    utf8_general_ci     None  max_rows=14425
# 59       None  latin1_swedish_ci     None
#
# [5 rows x 21 columns]

# %%
# stmt="show tables"
# df1=pd.read_sql(stmt,conn)
# df1.tail()
# Out:
#   Tables_in_project_itsm
# 0           dataset_list

# %%
# stmt="select * from dataset_list"
# df1=pd.read_sql(stmt,conn)
# df1.tail()
# Out:
#          CI_Name       CI_Cat                 CI_Subcat        WBS  \
# 46601  SBA000464  application  Server Based Application  WBS000073
# 46602  SBA000461  application  Server Based Application  WBS000073
# 46603  LAP000019     computer                    Laptop  WBS000091
# 46604  WBA000058  application     Web Based Application  WBS000073
# 46605  DCE000077     hardware       DataCenterEquipment  WBS000267
#
#       Incident_ID  Status Impact Urgency Priority   number_cnt  ...  \
# 46601   IM0047053  Closed      4       4        4   0.23189604  ...
# 46602   IM0047054  Closed      4       4        4  0.805153085  ...
# 46603   IM0047055  Closed      5       5        5  0.917466294  ...
# 46604   IM0047056  Closed      4       4        4  0.701278158  ...
# 46605   IM0047057  Closed      3       3        3  0.902319509  ...
#
#       Reopen_Time     Resolved_Time        Close_Time Handle_Time_hrs  \
# 46601              31-03-2014 16:29  31-03-2014 16:29           0,095
# 46602              31-03-2014 15:29  31-03-2014 15:29     0,428333333
# 46603              31-03-2014 15:32  31-03-2014 15:32     0,071666667
# 46604              31-03-2014 15:42  31-03-2014 15:42     0,116944444
# 46605              31-03-2014 22:47  31-03-2014 22:47     0,586388889
#
#       Closure_Code No_of_Related_Interactions Related_Interaction  \
# 46601        Other                          1           SD0147021
# 46602   User error                          1           SD0146967
# 46603     Hardware                          1           SD0146982
# 46604     Software                          1           SD0146986
# 46605     Hardware                          1           SD0147088
#
#       No_of_Related_Incidents No_of_Related_Changes Related_Change
# 46601
# 46602
# 46603
# 46604
# 46605
#
# [5 rows x 25 columns]

# %%
df1.to_csv("ABCdata.csv")

# %%
data=pd.read_csv("ABCdata.csv")
data.head(10)
# Out:
# /Users/sankhadeepchatterjee/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0    CI_Name          CI_Cat              CI_Subcat        WBS  \
# 0           0  SUB000508  subapplication  Web Based Application  WBS000162
# 1           1  WBA000124     application  Web Based Application  WBS000088
# 2           2  DTA000024     application    Desktop Application  WBS000092
# 3           3  WBA000124     application  Web Based Application  WBS000088
# 4           4  WBA000124     application  Web Based Application  WBS000088
# 5           5  WBA000124     application  Web Based Application  WBS000088
# 6           6  WBA000082     application  Web Based Application  WBS000055
# 7           7  WBA000124     application  Web Based Application  WBS000088
# 8           8  WBA000124     application  Web Based Application  WBS000088
# 9           9  WBA000082     application  Web Based Application  WBS000055
#
#   Incident_ID  Status Impact Urgency  Priority  ...       Reopen_Time  \
# 0   IM0000004  Closed      4       4       4.0  ...               NaN
# 1   IM0000005  Closed      3       3       3.0  ...  02-12-2013 12:31
# 2   IM0000006  Closed     NS       3       NaN  ...               NaN
# 3   IM0000011  Closed      4       4       4.0  ...               NaN
# 4   IM0000012  Closed      4       4       4.0  ...               NaN
# 5   IM0000013  Closed      4       4       4.0  ...               NaN
# 6   IM0000014  Closed      4       4       4.0  ...               NaN
# 7   IM0000015  Closed      4       4       4.0  ...               NaN
# 8   IM0000017  Closed     NS       3       NaN  ...               NaN
# 9   IM0000018  Closed      4       4       4.0  ...               NaN
#
#       Resolved_Time        Close_Time Handle_Time_hrs  \
# 0  04-11-2013 13:50  04-11-2013 13:51  3,87,16,91,111
# 1  02-12-2013 12:36  02-12-2013 12:36  4,35,47,86,389
# 2  13-01-2014 15:12  13-01-2014 15:13  4,84,31,19,444
# 3  14-11-2013 09:31  14-11-2013 09:31  4,32,18,33,333
# 4  08-11-2013 13:55  08-11-2013 13:55  3,38,39,03,333
# 5  08-11-2013 13:54  08-11-2013 13:54  3,38,34,36,944
# 6  27-12-2013 10:59  27-12-2013 10:59  3,70,31,91,389
# 7  08-11-2013 14:09  08-11-2013 14:09  3,29,46,24,167
# 8  08-11-2013 14:02  08-11-2013 14:02     0,862777778
# 9  08-11-2013 14:33  08-11-2013 14:35  3,21,15,26,944
#
#                    Closure_Code No_of_Related_Interactions  \
# 0                         Other                        1.0
# 1                      Software                        1.0
# 2  No error - works as designed                        1.0
# 3                Operator error                        1.0
# 4                         Other                        1.0
# 5                         Other                        1.0
# 6                       Unknown                        1.0
# 7                         Other                        1.0
# 8                         Other                        1.0
# 9  No error - works as designed                        1.0
#
#   Related_Interaction No_of_Related_Incidents No_of_Related_Changes  \
# 0           SD0000007                     2.0                   NaN
# 1           SD0000011                     1.0                   NaN
# 2           SD0000017                     NaN                   NaN
# 3           SD0000025                     NaN                   NaN
# 4           SD0000029                     NaN                   NaN
# 5           SD0000031                     NaN                   NaN
# 6           SD0000033                     NaN                   NaN
# 7           SD0000034                     NaN                   NaN
# 8           SD0000036                     NaN                   NaN
# 9           SD0000037                     NaN                   NaN
#
#   Related_Change
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
#
# [10 rows x 26 columns]

# %%
data.shape
# Out:
# (46606, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46606 entries, 0 to 46605
# Data columns (total 26 columns):
# Unnamed: 0                    46606 non-null int64
# CI_Name                       46606 non-null object
# CI_Cat                        46495 non-null object
# CI_Subcat                     46495 non-null object
# WBS                           46606 non-null object
# Incident_ID                   46606 non-null object
# Status                        46606 non-null object
# Impact                        46606 non-null object
# Urgency                       46606 non-null object
# Priority                      45226 non-null float64
# number_cnt                    46606 non-null float64
# Category                      46606 non-null object
# KB_number                     46606 non-null object
# Alert_Status                  46606 non-null object
# No_of_Reassignments           46605 non-null float64
# Open_Time                     46606 non-null object
# Reopen_Time                   2284 non-null object
# Resolved_Time                 44826 non-null object
# Close_Time                    46606 non-null object
# Handle_Time_hrs               46605 non-null object
# Closure_Code                  46146 non-null object
# No_of_Related_Interactions    46492 non-null float64
# Related_Interaction           46606 non-null object
# No_of_Related_Incidents       1222 non-null float64
# No_of_Related_Changes         560 non-null float64
# Related_Change                560 non-null object
# dtypes: float64(6), int64(1), object(19)
# memory usage: 9.2+ MB

# %%
# data.isnull().sum()

# %%
data['Impact'].replace(to_replace='NS', value=4, inplace=True)
# data['impact'].bfill

# %%
data.head()
# Out:
#    Unnamed: 0    CI_Name          CI_Cat              CI_Subcat        WBS  \
# 0           0  SUB000508  subapplication  Web Based Application  WBS000162
# 1           1  WBA000124     application  Web Based Application  WBS000088
# 2           2  DTA000024     application    Desktop Application  WBS000092
# 3           3  WBA000124     application  Web Based Application  WBS000088
# 4           4  WBA000124     application  Web Based Application  WBS000088
#
#   Incident_ID  Status Impact Urgency  Priority  ...       Reopen_Time  \
# 0   IM0000004  Closed      4       4       4.0  ...               NaN
# 1   IM0000005  Closed      3       3       3.0  ...  02-12-2013 12:31
# 2   IM0000006  Closed      4       3       NaN  ...               NaN
# 3   IM0000011  Closed      4       4       4.0  ...               NaN
# 4   IM0000012  Closed      4       4       4.0  ...               NaN
#
#       Resolved_Time        Close_Time Handle_Time_hrs  \
# 0  04-11-2013 13:50  04-11-2013 13:51  3,87,16,91,111
# 1  02-12-2013 12:36  02-12-2013 12:36  4,35,47,86,389
# 2  13-01-2014 15:12  13-01-2014 15:13  4,84,31,19,444
# 3  14-11-2013 09:31  14-11-2013 09:31  4,32,18,33,333
# 4  08-11-2013 13:55  08-11-2013 13:55  3,38,39,03,333
#
#                    Closure_Code No_of_Related_Interactions  \
# 0                         Other                        1.0
# 1                      Software                        1.0
# 2  No error - works as designed                        1.0
# 3                Operator error                        1.0
# 4                         Other                        1.0
#
#   Related_Interaction No_of_Related_Incidents No_of_Related_Changes  \
# 0           SD0000007                     2.0                   NaN
# 1           SD0000011                     1.0                   NaN
# 2           SD0000017                     NaN                   NaN
# 3           SD0000025                     NaN                   NaN
# 4           SD0000029                     NaN                   NaN
#
#   Related_Change
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 26 columns]

# %%
data['Priority'].fillna(data['Priority'].mean(),inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0    CI_Name          CI_Cat              CI_Subcat        WBS  \
# 0           0  SUB000508  subapplication  Web Based Application  WBS000162
# 1           1  WBA000124     application  Web Based Application  WBS000088
# 2           2  DTA000024     application    Desktop Application  WBS000092
# 3           3  WBA000124     application  Web Based Application  WBS000088
# 4           4  WBA000124     application  Web Based Application  WBS000088
#
#   Incident_ID  Status Impact Urgency  Priority  ...       Reopen_Time  \
# 0   IM0000004  Closed      4       4  4.000000  ...               NaN
# 1   IM0000005  Closed      3       3  3.000000  ...  02-12-2013 12:31
# 2   IM0000006  Closed      4       3  4.215805  ...               NaN
# 3   IM0000011  Closed      4       4  4.000000  ...               NaN
# 4   IM0000012  Closed      4       4  4.000000  ...               NaN
#
#       Resolved_Time        Close_Time Handle_Time_hrs  \
# 0  04-11-2013 13:50  04-11-2013 13:51  3,87,16,91,111
# 1  02-12-2013 12:36  02-12-2013 12:36  4,35,47,86,389
# 2  13-01-2014 15:12  13-01-2014 15:13  4,84,31,19,444
# 3  14-11-2013 09:31  14-11-2013 09:31  4,32,18,33,333
# 4  08-11-2013 13:55  08-11-2013 13:55  3,38,39,03,333
#
#                    Closure_Code No_of_Related_Interactions  \
# 0                         Other                        1.0
# 1                      Software                        1.0
# 2  No error - works as designed                        1.0
# 3                Operator error                        1.0
# 4                         Other                        1.0
#
#   Related_Interaction No_of_Related_Incidents No_of_Related_Changes  \
# 0           SD0000007                     2.0                   NaN
# 1           SD0000011                     1.0                   NaN
# 2           SD0000017                     NaN                   NaN
# 3           SD0000025                     NaN                   NaN
# 4           SD0000029                     NaN                   NaN
#
#   Related_Change
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 26 columns]

# %%
data['Reopen_Time'].fillna(method='bfill',inplace=True)
data['Reopen_Time'].fillna(method='ffill',inplace=True)

# %%
data.sort_values(['Reopen_Time'], ascending=True)
# Out:
#        Unnamed: 0    CI_Name          CI_Cat                 CI_Subcat  \
# 486           486  SBA000263     application  Server Based Application
# 485           485  DTA000616     application       Desktop Application
# 1089         1089  WBA000103     application     Web Based Application
# 1093         1093  WBA000008     application     Web Based Application
# 1092         1092  WBA000094     application     Web Based Application
# 1091         1091  LAP000433        computer                    Laptop
# 1090         1090  SUB000286  subapplication  Server Based Application
# 1088         1088  SBA000759     application  Server Based Application
# 1087         1087  DTA000616     application       Desktop Application
# 1086         1086  SBA000759     application  Server Based Application
# 1083         1083  SBA000607     application  Server Based Application
# 1082         1082  SUB000456  subapplication     Web Based Application
# 1085         1085  SBA000189     application  Server Based Application
# 1084         1084  SBA000172     application  Server Based Application
# 1094         1094  SBA000045     application  Server Based Application
# 1095         1095  SBA000088     application  Server Based Application
# 855           855  WBA000058     application     Web Based Application
# 854           854  DTA000031     application       Desktop Application
# 861           861  SBA000805     application  Server Based Application
# 858           858  DTA000189     application       Desktop Application
# 856           856  LAP000555        computer                    Laptop
# 857           857  DTA000015     application       Desktop Application
# 859           859  LAP001519        computer                    Laptop
# 860           860  SBA000834     application  Server Based Application
# 937           937  DTA000056     application       Desktop Application
# 938           938  WBA000133     application     Web Based Application
# 940           940  SBA000263     application  Server Based Application
# 941           941  SAP000004     application                       SAP
# 939           939  SAP000004     application                       SAP
# 656           656  SBA000698     application  Server Based Application
# ...           ...        ...             ...                       ...
# 24329       24329  WBA000011     application     Web Based Application
# 24328       24328  SBA000462     application  Server Based Application
# 24324       24324  WBA000124     application     Web Based Application
# 24326       24326  WBA000011     application     Web Based Application
# 24309       24309  CBA000014     application  Client Based Application
# 24310       24310  WBA000058     application     Web Based Application
# 24311       24311  SUB000443  subapplication     Web Based Application
# 24354       24354  SAP000004     application                       SAP
# 24313       24313  WBA000107     application     Web Based Application
# 24314       24314  KYB000001        hardware                  Keyboard
# 24315       24315  WBA000018     application     Web Based Application
# 24316       24316  WBA000107     application     Web Based Application
# 24312       24312  DSK000667        computer                   Desktop
# 24318       24318  SUB000149  subapplication  Server Based Application
# 24319       24319  WBA000144     application     Web Based Application
# 24320       24320  WBA000058     application     Web Based Application
# 24321       24321  WBA000124     application     Web Based Application
# 24322       24322  SAN000182         storage                       SAN
# 24323       24323  SUB000456  subapplication     Web Based Application
# 24325       24325  SBA000462     application  Server Based Application
# 24317       24317  DTA000025     application       Desktop Application
# 23759       23759  SBA000462     application  Server Based Application
# 23760       23760  SBA000759     application  Server Based Application
# 23761       23761  SUB000456  subapplication     Web Based Application
# 23765       23765  SUB000002  subapplication                    Citrix
# 23763       23763  SBA000263     application  Server Based Application
# 23764       23764  SUB000456  subapplication     Web Based Application
# 23766       23766  WBA000018     application     Web Based Application
# 23762       23762  SBA000458     application  Server Based Application
# 23758       23758  SUB000505  subapplication     Web Based Application
#
#              WBS Incident_ID  Status Impact Urgency  Priority  ...  \
# 486    WBS000072   IM0000567  Closed      5       5  5.000000  ...
# 485    WBS000089   IM0000566  Closed      3       3  3.000000  ...
# 1089   WBS000073   IM0001187  Closed      5       5  5.000000  ...
# 1093   WBS000167   IM0001191  Closed      5       5  5.000000  ...
# 1092   WBS000073   IM0001190  Closed      5       5  5.000000  ...
# 1091   WBS000091   IM0001189  Closed      5       5  5.000000  ...
# 1090   WBS000054   IM0001188  Closed      4       3  4.215805  ...
# 1088   WBS000296   IM0001186  Closed      4       4  4.000000  ...
# 1087   WBS000092   IM0001185  Closed      4       4  4.000000  ...
# 1086   WBS000296   IM0001184  Closed      4       4  4.000000  ...
# 1083   WBS000263   IM0001181  Closed      5       5  5.000000  ...
# 1082   WBS000073   IM0001180  Closed      4       4  4.000000  ...
# 1085   WBS000139   IM0001183  Closed      5       5  5.000000  ...
# 1084   WBS000014   IM0001182  Closed      3       3  3.000000  ...
# 1094   WBS000170   IM0001192  Closed      4       4  4.000000  ...
# 1095   WBS000017   IM0001193  Closed      3       3  3.000000  ...
# 855    WBS000073   IM0000950  Closed      4       4  4.000000  ...
# 854    WBS000111   IM0000949  Closed      5       5  5.000000  ...
# 861    WBS000016   IM0000956  Closed      4       3  4.215805  ...
# 858    WBS000092   IM0000953  Closed      4       4  4.000000  ...
# 856    WBS000091   IM0000951  Closed      5       5  5.000000  ...
# 857    WBS000093   IM0000952  Closed      4       4  4.000000  ...
# 859    WBS000091   IM0000954  Closed      5       5  5.000000  ...
# 860    WBS000223   IM0000955  Closed      4       4  4.000000  ...
# 937    WBS000091   IM0001034  Closed      4       4  4.000000  ...
# 938    WBS000073   IM0001035  Closed      4       4  4.000000  ...
# 940    WBS000072   IM0001037  Closed      5       5  5.000000  ...
# 941    WBS000271   IM0001038  Closed      5       5  5.000000  ...
# 939    WBS000271   IM0001036  Closed      5       5  5.000000  ...
# 656    WBS000090   IM0000746  Closed      4       4  4.000000  ...
# ...          ...         ...     ...    ...     ...       ...  ...
# 24329  WBS000152   IM0024586  Closed      5       5  5.000000  ...
# 24328  WBS000073   IM0024585  Closed      4       4  4.000000  ...
# 24324  WBS000088   IM0024581  Closed      4       4  4.000000  ...
# 24326  WBS000152   IM0024583  Closed      5       5  5.000000  ...
# 24309  WBS000073   IM0024566  Closed      4       4  4.000000  ...
# 24310  WBS000073   IM0024567  Closed      4       4  4.000000  ...
# 24311  WBS000125   IM0024568  Closed      5       5  5.000000  ...
# 24354  WBS000271   IM0024612  Closed      5       5  5.000000  ...
# 24313  WBS000162   IM0024570  Closed      4       4  4.000000  ...
# 24314  WBS000091   IM0024571  Closed      5       5  5.000000  ...
# 24315  WBS000073   IM0024572  Closed      4       4  4.000000  ...
# 24316  WBS000162   IM0024573  Closed      4       4  4.000000  ...
# 24312  WBS000091   IM0024569  Closed      5       5  5.000000  ...
# 24318  WBS000162   IM0024575  Closed      4       4  4.000000  ...
# 24319  WBS000318   IM0024576  Closed      5       5  5.000000  ...
# 24320  WBS000073   IM0024577  Closed      4       4  4.000000  ...
# 24321  WBS000088   IM0024578  Closed      4       4  4.000000  ...
# 24322  WBS000128   IM0024579  Closed      5       5  5.000000  ...
# 24323  WBS000073   IM0024580  Closed      4       4  4.000000  ...
# 24325  WBS000073   IM0024582  Closed      4       4  4.000000  ...
# 24317  WBS000110   IM0024574  Closed      5       5  5.000000  ...
# 23759  WBS000073   IM0024009  Closed      4       4  4.000000  ...
# 23760  WBS000296   IM0024010  Closed      5       5  5.000000  ...
# 23761  WBS000073   IM0024011  Closed      4       4  4.000000  ...
# 23765  WBS000098   IM0024015  Closed      4       4  4.000000  ...
# 23763  WBS000072   IM0024013  Closed      5       5  5.000000  ...
# 23764  WBS000073   IM0024014  Closed      4       4  4.000000  ...
# 23766  WBS000073   IM0024016  Closed      4       4  4.000000  ...
# 23762  WBS000073   IM0024012  Closed      4       4  4.000000  ...
# 23758  WBS000162   IM0024008  Closed      4       4  4.000000  ...
#
#             Reopen_Time     Resolved_Time        Close_Time Handle_Time_hrs  \
# 486    01-10-2013 09:58  01-10-2013 10:16  01-10-2013 10:16     0,018333333
# 485    01-10-2013 09:58  24-01-2014 10:44  24-01-2014 10:44  8,54,05,55,556
# 1089   01-10-2013 10:20  28-10-2013 12:40  28-10-2013 12:40  1,91,20,58,333
# 1093   01-10-2013 10:20  07-10-2013 15:12  07-10-2013 15:12  4,38,21,66,667
# 1092   01-10-2013 10:20  02-10-2013 09:23  02-10-2013 09:23  1,54,38,88,889
# 1091   01-10-2013 10:20  07-10-2013 13:10  07-10-2013 13:10  1,50,15,55,556
# 1090   01-10-2013 10:20  31-10-2013 13:13  31-10-2013 13:13  2,08,33,33,333
# 1088   01-10-2013 10:20  08-10-2013 14:30  08-10-2013 14:30  1,85,16,66,667
# 1087   01-10-2013 10:20  02-10-2013 14:34  02-10-2013 14:34  1,94,89,16,667
# 1086   01-10-2013 10:20  03-10-2013 16:58  03-10-2013 16:58  3,25,16,94,444
# 1083   01-10-2013 10:20  15-10-2013 23:27  15-10-2013 23:27  1,17,79,27,778
# 1082   01-10-2013 10:20  01-10-2013 14:46  01-10-2013 14:46  9,57,44,44,444
# 1085   01-10-2013 10:20  04-10-2013 13:59  04-10-2013 13:59  4,02,09,44,444
# 1084   01-10-2013 10:20  07-10-2013 08:05  07-10-2013 08:06  4,48,23,05,556
# 1094   01-10-2013 10:20  02-10-2013 13:21  02-10-2013 13:21          0,7125
# 1095   01-10-2013 10:20  04-10-2013 14:42  04-10-2013 14:42  2,35,60,83,333
# 855    01-10-2013 10:22  10-10-2013 07:28  10-10-2013 07:28     0,962777778
# 854    01-10-2013 10:22  11-10-2013 08:43  11-10-2013 08:43  4,81,85,27,778
# 861    01-10-2013 10:22  01-10-2013 13:44  01-10-2013 13:44  1,68,93,88,889
# 858    01-10-2013 10:22  07-10-2013 08:40  07-10-2013 08:40        6,19,575
# 856    01-10-2013 10:22  04-10-2013 09:43  04-10-2013 09:43  5,24,20,27,778
# 857    01-10-2013 10:22  03-10-2013 16:31  03-10-2013 16:32  4,68,53,33,333
# 859    01-10-2013 10:22  11-10-2013 14:57  11-10-2013 14:57  8,96,45,83,333
# 860    01-10-2013 10:22  02-10-2013 08:33  02-10-2013 08:33  2,95,75,55,556
# 937    01-10-2013 11:06  11-10-2013 09:02  11-10-2013 09:03  1,21,38,88,889
# 938    01-10-2013 11:06  01-10-2013 11:29  01-10-2013 11:29  7,17,27,77,778
# 940    01-10-2013 11:06  01-10-2013 10:30  01-10-2013 10:30     0,060277778
# 941    01-10-2013 11:06  02-10-2013 11:41  02-10-2013 11:41  1,43,69,44,444
# 939    01-10-2013 11:06  01-10-2013 12:09  01-10-2013 12:09  1,16,88,33,333
# 656    01-10-2013 11:08  11-10-2013 12:44  11-10-2013 12:44           0,675
# ...                 ...               ...               ...             ...
# 24329  31-12-2013 11:52  03-02-2014 15:28  03-02-2014 15:29  1,38,98,72,222
# 24328  31-12-2013 11:52  31-12-2013 08:46  31-12-2013 08:46  3,02,44,44,444
# 24324  31-12-2013 11:52  31-12-2013 10:34  31-12-2013 10:34  5,14,52,77,778
# 24326  31-12-2013 11:52  30-12-2013 16:07  30-12-2013 16:09          0,1275
# 24309  31-12-2013 11:52               NaN  31-12-2013 12:10  5,75,38,88,889
# 24310  31-12-2013 11:52  30-12-2013 15:18  30-12-2013 15:18     0,616111111
# 24311  31-12-2013 11:52  02-01-2014 10:35  02-01-2014 10:36  1,67,33,33,333
# 24354  31-12-2013 11:52  02-01-2014 07:56  02-01-2014 07:56  1,17,39,72,222
# 24313  31-12-2013 11:52               NaN  03-01-2014 15:41  3,18,95,83,333
# 24314  31-12-2013 11:52  30-12-2013 16:02  30-12-2013 16:02     0,006666667
# 24315  31-12-2013 11:52  07-01-2014 08:46  07-01-2014 08:46            5,82
# 24316  31-12-2013 11:52  21-02-2014 08:35  21-02-2014 08:35  3,64,05,69,444
# 24312  31-12-2013 11:52  06-01-2014 15:57  06-01-2014 15:57  4,30,88,33,333
# 24318  31-12-2013 11:52  25-03-2014 12:09  25-03-2014 12:09  6,26,57,55,556
# 24319  31-12-2013 11:52  15-01-2014 13:39  15-01-2014 13:39  3,44,66,66,667
# 24320  31-12-2013 11:52  30-12-2013 15:50  30-12-2013 15:50     0,146388889
# 24321  31-12-2013 11:52  02-01-2014 09:25  02-01-2014 09:25  1,47,14,16,667
# 24322  31-12-2013 11:52  02-01-2014 09:26  02-01-2014 09:26  1,46,47,77,778
# 24323  31-12-2013 11:52  30-12-2013 16:36  30-12-2013 16:36          0,7375
# 24325  31-12-2013 11:52  30-12-2013 16:38  30-12-2013 16:39     0,642777778
# 24317  31-12-2013 11:52  31-12-2013 14:39  31-12-2013 14:39  9,67,63,88,889
# 23759  31-12-2013 14:06  24-12-2013 13:59  24-12-2013 13:59     0,133333333
# 23760  31-12-2013 14:06  24-12-2013 15:19  24-12-2013 15:19  1,29,13,88,889
# 23761  31-12-2013 14:06  24-12-2013 14:43  24-12-2013 14:43          0,6225
# 23765  31-12-2013 14:06  30-12-2013 13:11  30-12-2013 13:11  2,21,43,33,333
# 23763  31-12-2013 14:06  15-01-2014 08:46  15-01-2014 08:46  1,30,99,19,444
# 23764  31-12-2013 14:06  24-12-2013 14:48  24-12-2013 14:49     0,526388889
# 23766  31-12-2013 14:06  31-12-2013 14:37  31-12-2013 14:37  1,94,27,77,778
# 23762  31-12-2013 14:06  06-01-2014 15:16  06-01-2014 15:16  5,67,41,38,889
# 23758  31-12-2013 14:06  24-12-2013 14:25  24-12-2013 14:26     0,585555556
#
#                        Closure_Code No_of_Related_Interactions  \
# 486                           Other                        1.0
# 485                            Data                        1.0
# 1089                       Software                        1.0
# 1093                       Software                        1.0
# 1092                          Other                        1.0
# 1091                       Hardware                        1.0
# 1090                       Software                        1.0
# 1088                          Other                        1.0
# 1087                       Referred                        1.0
# 1086                           Data                        1.0
# 1083                          Other                        1.0
# 1082   No error - works as designed                        1.0
# 1085                          Other                        NaN
# 1084                       Software                       34.0
# 1094                     User error                        1.0
# 1095   No error - works as designed                        2.0
# 855                      User error                        1.0
# 854    No error - works as designed                        1.0
# 861                        Hardware                        2.0
# 858                           Other                        1.0
# 856                           Other                        1.0
# 857                        Software                        1.0
# 859                        Software                        1.0
# 860                        Software                        1.0
# 937                        Software                        2.0
# 938                         Unknown                        1.0
# 940                           Other                        1.0
# 941                           Other                        2.0
# 939                           Other                        1.0
# 656                        Software                        1.0
# ...                             ...                        ...
# 24329                      Software                        1.0
# 24328                         Other                        1.0
# 24324                      Software                        1.0
# 24326                    User error                        1.0
# 24309                      Software                        1.0
# 24310                         Other                        1.0
# 24311  No error - works as designed                        1.0
# 24354                         Other                        2.0
# 24313                         Other                        1.0
# 24314                      Hardware                        1.0
# 24315                      Software                        1.0
# 24316                      Software                        1.0
# 24312                      Software                        1.0
# 24318                         Other                        1.0
# 24319                Operator error                        1.0
# 24320                      Software                        1.0
# 24321                      Software                        1.0
# 24322          User manual not used                        1.0
# 24323  No error - works as designed                        1.0
# 24325                      Software                        1.0
# 24317                      Referred                        1.0
# 23759                Operator error                        1.0
# 23760                         Other                        1.0
# 23761                         Other                        1.0
# 23765                      Hardware                        1.0
# 23763                         Other                        1.0
# 23764                         Other                        1.0
# 23766                         Other                        2.0
# 23762                         Other                        1.0
# 23758  No error - works as designed                        1.0
#
#       Related_Interaction No_of_Related_Incidents No_of_Related_Changes  \
# 486             SD0000787                     NaN                   NaN
# 485             SD0000772                     NaN                   NaN
# 1089            SD0001512                     NaN                   NaN
# 1093            SD0001442                     NaN                   NaN
# 1092            SD0001438                     NaN                   NaN
# 1091            SD0001515                     NaN                   NaN
# 1090            SD0001513                     NaN                   NaN
# 1088            SD0001514                     NaN                   NaN
# 1087            SD0001511                     NaN                   NaN
# 1086            SD0001510                     NaN                   NaN
# 1083            SD0001506                     NaN                   NaN
# 1082            SD0001507                     NaN                   NaN
# 1085                 #N/B                     NaN                   NaN
# 1084          #MULTIVALUE                     NaN                   NaN
# 1094            SD0001441                     NaN                   NaN
# 1095          #MULTIVALUE                     NaN                   NaN
# 855             SD0001179                     NaN                   NaN
# 854             SD0001178                     NaN                   NaN
# 861           #MULTIVALUE                     NaN                   NaN
# 858             SD0001208                     NaN                   NaN
# 856             SD0001177                     NaN                   NaN
# 857             SD0001209                     NaN                   NaN
# 859             SD0001210                     NaN                   NaN
# 860             SD0001213                     NaN                   NaN
# 937           #MULTIVALUE                     NaN                   NaN
# 938             SD0001344                     NaN                   NaN
# 940             SD0001346                     NaN                   NaN
# 941           #MULTIVALUE                     NaN                   NaN
# 939             SD0001345                     NaN                   NaN
# 656             SD0000961                     NaN                   NaN
# ...                   ...                     ...                   ...
# 24329           SD0073471                     NaN                   NaN
# 24328           SD0073459                     NaN                   NaN
# 24324           SD0073451                     NaN                   NaN
# 24326           SD0073457                     NaN                   NaN
# 24309           SD0073532                     1.0                   NaN
# 24310           SD0073124                     NaN                   NaN
# 24311           SD0073131                     NaN                   NaN
# 24354         #MULTIVALUE                     NaN                   NaN
# 24313           SD0073433                     NaN                   NaN
# 24314           SD0073437                     NaN                   NaN
# 24315           SD0073432                     NaN                   NaN
# 24316           SD0073438                     NaN                   NaN
# 24312           SD0073129                     NaN                   NaN
# 24318           SD0073441                     NaN                   NaN
# 24319           SD0073442                     NaN                   NaN
# 24320           SD0073445                     NaN                   NaN
# 24321           SD0073446                     2.0                   NaN
# 24322           SD0073447                     NaN                   NaN
# 24323           SD0073448                     NaN                   NaN
# 24325           SD0073454                     NaN                   NaN
# 24317           SD0073435                     NaN                   NaN
# 23759           SD0071612                     NaN                   NaN
# 23760           SD0071621                     NaN                   NaN
# 23761           SD0071624                     NaN                   NaN
# 23765           SD0071272                     NaN                   NaN
# 23763           SD0071718                     NaN                   NaN
# 23764           SD0071634                     NaN                   NaN
# 23766         #MULTIVALUE                     NaN                   NaN
# 23762           SD0071633                     NaN                   NaN
# 23758           SD0071615                     NaN                   NaN
#
#       Related_Change
# 486              NaN
# 485              NaN
# 1089             NaN
# 1093             NaN
# 1092             NaN
# 1091             NaN
# 1090             NaN
# 1088             NaN
# 1087             NaN
# 1086             NaN
# 1083             NaN
# 1082             NaN
# 1085             NaN
# 1084             NaN
# 1094             NaN
# 1095             NaN
# 855              NaN
# 854              NaN
# 861              NaN
# 858              NaN
# 856              NaN
# 857              NaN
# 859              NaN
# 860              NaN
# 937              NaN
# 938              NaN
# 940              NaN
# 941              NaN
# 939              NaN
# 656              NaN
# ...              ...
# 24329            NaN
# 24328            NaN
# 24324            NaN
# 24326            NaN
# 24309            NaN
# 24310            NaN
# 24311            NaN
# 24354            NaN
# 24313            NaN
# 24314            NaN
# 24315            NaN
# 24316            NaN
# 24312            NaN
# 24318            NaN
# 24319            NaN
# 24320            NaN
# 24321            NaN
# 24322            NaN
# 24323            NaN
# 24325            NaN
# 24317            NaN
# 23759            NaN
# 23760            NaN
# 23761            NaN
# 23765            NaN
# 23763            NaN
# 23764            NaN
# 23766            NaN
# 23762            NaN
# 23758            NaN
#
# [46606 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46606 entries, 0 to 46605
# Data columns (total 26 columns):
# Unnamed: 0                    46606 non-null int64
# CI_Name                       46606 non-null object
# CI_Cat                        46495 non-null object
# CI_Subcat                     46495 non-null object
# WBS                           46606 non-null object
# Incident_ID                   46606 non-null object
# Status                        46606 non-null object
# Impact                        46606 non-null object
# Urgency                       46606 non-null object
# Priority                      46606 non-null float64
# number_cnt                    46606 non-null float64
# Category                      46606 non-null object
# KB_number                     46606 non-null object
# Alert_Status                  46606 non-null object
# No_of_Reassignments           46605 non-null float64
# Open_Time                     46606 non-null object
# Reopen_Time                   46606 non-null object
# Resolved_Time                 44826 non-null object
# Close_Time                    46606 non-null object
# Handle_Time_hrs               46605 non-null object
# Closure_Code                  46146 non-null object
# No_of_Related_Interactions    46492 non-null float64
# Related_Interaction           46606 non-null object
# No_of_Related_Incidents       1222 non-null float64
# No_of_Related_Changes         560 non-null float64
# Related_Change                560 non-null object
# dtypes: float64(6), int64(1), object(19)
# memory usage: 9.2+ MB
